# %% [markdown]
# # April Code pudding Project (Youtube Sentiment Analysis)

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
  
import seaborn as sns
import re
import os

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from wordcloud import WordCloud

import xgboost as xgb
from textblob import TextBlob

from tqdm import tqdm

# %% [markdown]
# ## Data Overview

# %%
dataset_path = os.path.join('..', 'datasets', 'archive')

comments = pd.read_csv(
    os.path.join(dataset_path, 'UScomments.csv'),
    on_bad_lines='skip',
    encoding='utf-8',
    low_memory=False
)
videos = pd.read_csv(
    os.path.join(dataset_path, 'USvideos.csv'), 
    on_bad_lines='skip', 
    encoding='utf-8')

# %%
comments = pd.read_csv(r'C:\Jeel Faldu\Data Scientist\Projects\april_code_jam_pudding\youtube_sentiment_analysis\datasets\archive\UScomments.csv', 
                       on_bad_lines='skip', 
                       encoding= 'utf-8', 
                       low_memory=False)

# %%
videos = pd.read_csv(r'C:\Jeel Faldu\Data Scientist\Projects\april_code_jam_pudding\youtube_sentiment_analysis\datasets\archive\USvideos.csv', 
                       on_bad_lines='skip', 
                       encoding= 'utf-8', 
                       low_memory=False)

# %%
display(comments.head(5)) # Display the first 5 rows of the comments DataFrame
# Out:
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4  XpVt6Z1Gjjo                                         trending 😉     3
#
#   replies
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
display(videos.head(5)) # Display the first 5 rows of the videos DataFrame
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2  cLdxuaxaQwc                                        My Response
# 3  WYYvHb03Eog                          Apple iPhone X first look
# 4  sjlHnJvXdQs                                  iPhone X (parody)
#
#       channel_title  category_id  \
# 0  Logan Paul Vlogs           24
# 1             Apple           28
# 2         PewDiePie           22
# 3         The Verge           28
# 4        jacksfilms           23
#
#                                                 tags    views   likes  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 1  Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lig...  7860119  185853
# 2                                             [none]  5845909  576597
# 3  apple iphone x hands on|Apple iPhone X|iPhone ...  2642103   24975
# ...

# %%
videos.shape
# Out:
# (7992, 11)

# %%
comments.shape
# Out:
# (691400, 4)

# %%
comments.info() # Display information about the comments DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691400 entries, 0 to 691399
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   video_id      691400 non-null  object
#  1   comment_text  691374 non-null  object
#  2   likes         691400 non-null  object
#  3   replies       691400 non-null  object
# dtypes: object(4)
# memory usage: 21.1+ MB

# %%
videos.info() # Display information about the videos DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7992 entries, 0 to 7991
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        7992 non-null   object
#  1   title           7992 non-null   object
#  2   channel_title   7992 non-null   object
#  3   category_id     7992 non-null   int64
#  4   tags            7992 non-null   object
#  5   views           7992 non-null   int64
#  6   likes           7992 non-null   int64
#  7   dislikes        7992 non-null   int64
#  8   comment_total   7992 non-null   int64
#  9   thumbnail_link  7992 non-null   object
#  10  date            7992 non-null   float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 686.9+ KB

# %%
comments.describe() # Display descriptive statistics of the comments DataFrame
# Out:
#            video_id comment_text   likes replies
# count        691400       691374  691400  691400
# unique         2266       434075    1060     369
# top     XpVt6Z1Gjjo          Lol       0       0
# freq            800          310  563752  649366

# %%
videos.info() # Display information about the videos DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7992 entries, 0 to 7991
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        7992 non-null   object
#  1   title           7992 non-null   object
#  2   channel_title   7992 non-null   object
#  3   category_id     7992 non-null   int64
#  4   tags            7992 non-null   object
#  5   views           7992 non-null   int64
#  6   likes           7992 non-null   int64
#  7   dislikes        7992 non-null   int64
#  8   comment_total   7992 non-null   int64
#  9   thumbnail_link  7992 non-null   object
#  10  date            7992 non-null   float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 686.9+ KB

# %%
comments.isna().sum() # Check for missing values in the comments DataFrame
comments.isna().sum()/len(comments) # Check for missing values in the comments DataFrame as a percentage
# Out:
# video_id        0.000000
# comment_text    0.000038
# likes           0.000000
# replies         0.000000
# dtype: float64

# %%
comments.dropna(subset=['comment_text'], inplace=True) # Drop rows with missing values in the 'comment_text' column

# %%
videos.isna().sum() # Check for missing values in the videos DataFrame
# Out:
# video_id          0
# title             0
# channel_title     0
# category_id       0
# tags              0
# views             0
# likes             0
# dislikes          0
# comment_total     0
# thumbnail_link    0
# date              0
# dtype: int64

# %%
comments_duplicates = comments.duplicated().sum() # Check for duplicate rows in the comments DataFrame
display(comments_duplicates) # Display the number of duplicate rows in the comments DataFrame
# Out:
# 219743

# %%
videos_duplicates = videos.duplicated().sum() # Check for duplicate rows in the comments DataFrame
display(videos_duplicates) # Display the number of duplicate rows in the comments DataFrame
# Out:
# 0

# %%
def clear_text(text):
    text = text.lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^a-z\s]","", text)
    text = text.split()
    return " ".join(text)

# %%
comments['clean_text'] = comments['comment_text'].astype(str).apply(clear_text) # Apply the clear_text function to the 'comment_text' column
comments= comments.drop(columns=['comment_text'])

# %%
comments.shape
display(comments.head(5)) # Display the first 5 rows of the comments DataFrame after cleaning
# Out:
#       video_id likes replies  \
# 0  XpVt6Z1Gjjo     4       0
# 1  XpVt6Z1Gjjo     3       0
# 2  XpVt6Z1Gjjo     3       0
# 3  XpVt6Z1Gjjo     3       0
# 4  XpVt6Z1Gjjo     3       0
#
#                                           clean_text
# 0                          logan paul its yo big day
# 1  ive been following you from the start of your ...
# 2                 say hi to kong and maverick for me
# 3                                  my fan attendance
# 4                                           trending

# %%
nltk.download('punkt')
print(nltk.data.path)
nltk.download('wordnet')
# Out:
# ['C:\\Users\\jeelf/nltk_data', 'c:\\Users\\jeelf\\anaconda3\\nltk_data', 'c:\\Users\\jeelf\\anaconda3\\share\\nltk_data', 'c:\\Users\\jeelf\\anaconda3\\lib\\nltk_data', 'C:\\Users\\jeelf\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jeelf\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jeelf\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
print(comments['clean_text'].isna().sum())  # Check for missing values
# Out:
# 0

# %%
lemmatizer = WordNetLemmatizer() # Initialize the lemmatizer

def lemmatize_text(text):
    tokens = word_tokenize(text)
    lemmas = [lemmatizer.lemmatize(token) for token in tokens]
    return " ".join(lemmas)

# %%
comments['clean_text'] = comments['clean_text'].astype(str).apply(lemmatize_text) # Apply the clear_text function to the 'comment_text' column
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 comments['clean_text'] = comments['clean_text'].astype(str).apply(lemmatize_text)
#
# File c:\Users\jeelf\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...
